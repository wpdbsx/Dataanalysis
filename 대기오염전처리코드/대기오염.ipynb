# %%
import pandas as pd

# %%
path='C:/Users/admin/Desktop/py_projects/project2/airqdata/2017년1월.xlsx'
air_q= pd.read_excel(path, encoding='CP949')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-6-cd7477e183b6> in <module>()
#       1 path='C:/Users/admin/Desktop/py_projects/project2/airqdata/2017년1월.xlsx'
# ----> 2 air_q= pd.read_excel(path, encoding='CP949')
#
# /usr/local/lib/python3.6/dist-packages/pandas/io/excel/_base.py in read_excel(io, sheet_name, header, names, index_col, usecols, squeeze, dtype, engine, converters, true_values, false_values, skiprows, nrows, na_values, keep_default_na, verbose, parse_dates, date_parser, thousands, comment, skipfooter, convert_float, mangle_dupe_cols, **kwds)
#     302
#     303     if not isinstance(io, ExcelFile):
# --> 304         io = ExcelFile(io, engine=engine)
#     305     elif engine and engine != io.engine:
#     306         raise ValueError(
#
# /usr/local/lib/python3.6/dist-packages/pandas/io/excel/_base.py in __init__(self, io, engine)
# ...

# %%
#/content/drive/My Drive/2조 project2/대기오염/서울시_기간별_시간평균_대기환경_정보_2020.04.csv
path='/content/drive/My Drive/2조 project2/대기오염/'
air_q= pd.read_csv(path+'서울시_기간별_시간평균_대기환경_정보_2020.04.csv', encoding='CP949')
len(air_q['측정소코드'].unique())
# https://data.seoul.go.kr/dataList/OA-2221/S/1/datasetView.do#
# 도시 측정소만 포함됨
# Out:
# 25

# %%
# /content/drive/My Drive/2조 project2/대기오염/2020년 1월.xlsx
path='/content/drive/My Drive/2조 project2/대기오염/'
# 전국 데이터, 최종 데이터
# 서울 지역 데이터만 추려서, 측정소 확인
# 일별/ 시간별(요일별, 출퇴근, 주말)/ 계절별( 황사 영향 )/ 날씨 영향( 비 오는 날 ) /
air_q= pd.read_excel(path+'2020년 1월.xlsx', encoding='CP949')

# %%
#air_q[air_q['측정소코드']=='도로변대기']
air_q=air_q[air_q['주소'].str.contains('서울')]
len(air_q['측정소명'].unique())
# 도시 측정소 25 + 도로변 측정소 15
# Out:
# 40

# %%
# https://www.airkorea.or.kr/web/khaiInfo?pMENU_NO=129 (대기환경 평가 지수)
air_q
# Out:
#            지역      망   측정소코드 측정소명  ...    NO2  PM10  PM25              주소
# 0       서울 중구   도시대기  111121   중구  ...  0.036  24.0  19.0   서울 중구 덕수궁길 15
# 1       서울 중구   도시대기  111121   중구  ...  0.039  25.0  21.0   서울 중구 덕수궁길 15
# 2       서울 중구   도시대기  111121   중구  ...  0.037  29.0  23.0   서울 중구 덕수궁길 15
# 3       서울 중구   도시대기  111121   중구  ...  0.036  26.0  22.0   서울 중구 덕수궁길 15
# 4       서울 중구   도시대기  111121   중구  ...  0.035  25.0  19.0   서울 중구 덕수궁길 15
# ...       ...    ...     ...  ...  ...    ...   ...   ...             ...
# 29755  서울 노원구  도로변대기  111312  화랑로  ...  0.040  41.0  30.0  서울 노원구 화랑로 429
# 29756  서울 노원구  도로변대기  111312  화랑로  ...  0.045  49.0  34.0  서울 노원구 화랑로 429
# 29757  서울 노원구  도로변대기  111312  화랑로  ...  0.044  47.0  33.0  서울 노원구 화랑로 429
# 29758  서울 노원구  도로변대기  111312  화랑로  ...  0.038  46.0  35.0  서울 노원구 화랑로 429
# 29759  서울 노원구  도로변대기  111312  화랑로  ...  0.042  45.0  33.0  서울 노원구 화랑로 429
#
# [29760 rows x 12 columns]

# %%
air_q.dtypes
# Out:
# 지역        object
# 망         object
# 측정소코드      int64
# 측정소명      object
# 측정일시       int64
# SO2      float64
# CO       float64
# O3       float64
# NO2      float64
# PM10     float64
# PM25     float64
# 주소        object
# dtype: object

# %%
import datetime
air_q['측정일시']
for item in air_q['측정일시']:
  i=datetime.datetime.strptime(str(item), "%Y%m%d%H")
  print(i.weekday())
  break
# Out:
# 2
