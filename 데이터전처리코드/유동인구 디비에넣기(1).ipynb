# %%
# pip install wheel

# %%
# !pip install plotly

# %%
# pip install matplotlib

# %%
# pip install pandas

# %%
# pip install xlrd

# %%
# pip install folium

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import matplotlib 

#  df     = pd.DataFrame(credit_card_region_age)
# credit_card_region_age
# df.head()
# credit_card_region_age
# credit_card_data[credit_card_data['구분코드(pop_cd)'][i].find('L') ==1 ]
# credit_card_data[credit_card_data['구분코드(pop_cd)'].isin(['L0'])==1]
# credit_card_region_age = credit_card_data[credit_card_data['구분코드(pop_cd)'].map(lambda x : 'L' in x)]
# credit_card_age_sex = credit_card_data[credit_card_data['구분코드(pop_cd)'].map(lambda x : 'Y' in x)]

# %%
#2 버전 확인
np.__version__, pd.__version__
# Out:
# ('1.16.4', '1.0.5')

# %%
# pip install matplotlib

# %%
# 행정동 코드 
# 서울시_행정_법정동_코드.xlsx 
#CP949
path = 'D:/데이터/법정동코드/서울시_행정_법정동_코드.xlsx ' 
a=pd.read_excel(path,encoding='utf-8')
# 주어진 데이터의 컬럼 파트가 3개 라인을 사용하고 있어서 실제 데이터가 아닌 부분도 데이터로 표현이 된다.
# Case.columns =  [ '케이스번호','도시이름','구이름','그룹유무','감염경로','몇번째확진자','위도','경도']
a.head()
# Out:
#    자치구     행정동코드    행정동     법정동코드  법정동
# 0  종로구  11110515  청운효자동  11110101  청운동
# 1  종로구  11110515  청운효자동  11110102  신교동
# 2  종로구  11110515  청운효자동  11110103  궁정동
# 3  종로구  11110515  청운효자동  11110104  효자동
# 4  종로구  11110515  청운효자동  11110105  창성동

# %%
a =a.sort_values(by='행정동코드')

# %%
a['행정동코드'].unique()
# Out:
# array([11110515, 11110530, 11110540, 11110550, 11110560, 11110570,
#        11110580, 11110600, 11110615, 11110630, 11110640, 11110650,
#        11110660, 11110670, 11110680, 11110690, 11110700, 11110710,
#        11140520, 11140540, 11140550, 11140570, 11140580, 11140590,
#        11140605, 11140610, 11140620, 11140630, 11140640, 11140650,
#        11140660, 11140670, 11140680, 11170510, 11170520, 11170530,
#        11170555, 11170560, 11170570, 11170580, 11170590, 11170625,
#        11170630, 11170640, 11170650, 11170660, 11170685, 11170690,
#        11170700, 11200520, 11200535, 11200540, 11200550, 11200560,
#        11200570, 11200580, 11200590, 11200615, 11200620, 11200645,
#        11200650, 11200660, 11200670, 11200690, 11200720, 11200790,
#        11215710, 11215730, 11215740, 11215750, 11215760, 11215770,
#        11215780, 11215810, 11215820, 11215830, 11215840, 11215847,
#        11215850, 11215860, 11215870, 11230536, 11230545, 11230560,
# ...

# %%
a2= a[['행정동코드','행정동']]

# %%
pip install distributed
# Out:
# ...
#   Created wheel for toolz: filename=toolz-0.10.0-py3-none-any.whl size=55580 sha256=928c3c13f36bfcecafc5d766ca540cd4ebe7d274eb0e29fe12933ded4983d22c
#   Stored in directory: c:\users\master\appdata\local\pip\cache\wheels\e2\83\7c\248063997a4f9ff6bf145822e620e8c37117a6b4c765584077
# Successfully built toolz
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install modin

# %%
import modin.pandas as pd4

# %%
path = f'D:/데이터/유동인구/LOCAL_PEOPLE_DONG_202001.csv' 
b =pd.read_csv(path,encoding='utf-8')
# 주어진 데이터의 컬럼 파트가 3개 라인을 사용하고 있어서 실제 데이터가 아닌 부분도 데이터로 표현이 된다.
# Case.columns =  [ '케이스번호','도시이름','구이름','그룹유무','감염경로','몇번째확진자','위도','경도']
b.reset_index(inplace=True)
bcolumns = b.columns
 
b.drop('여자70세이상생활인구수',axis=1,inplace=True)
b.drop('여자55세부터59세생활인구수',axis=1,inplace=True)
b.drop('여자50세부터54세생활인구수',axis=1,inplace=True)
b.drop('여자65세부터69세생활인구수',axis=1,inplace=True)
b.drop('여자60세부터64세생활인구수',axis=1,inplace=True)
b.drop('여자45세부터49세생활인구수',axis=1,inplace=True)


b.columns =  bcolumns[6:]
# len(bcolumns[6:]) , len(b.columns )

# %%
b
# Out:
#            기준일ID  시간대구분     행정동코드      총생활인구수  남자0세부터9세생활인구수  남자10세부터14세생활인구수  \
# 0       20200101      0  11620625  24188.5806       870.1487         439.6648
# 1       20200101      0  11140605   6716.5334        89.0565          36.2822
# 2       20200101      0  11470640  46603.6243      2164.9685        1254.3274
# 3       20200101      0  11290780   9589.1813       390.6835         244.4328
# 4       20200101      0  11320512  29984.1309      1005.9128         506.6446
# ...          ...    ...       ...         ...            ...              ...
# 315451  20200131     23  11260690  20052.7278       784.8522         457.1949
# 315452  20200131     23  11140570   7758.9907       143.6706          47.8903
# 315453  20200131     23  11590605  34441.9618      1054.0754         489.3910
# 315454  20200131     23  11215760  17221.9293       535.6532         264.8733
# 315455  20200131     23  11200580  15466.1528       629.6817         386.2273
#
# ...

# %%
# 행정동 코드 
# 유동인구 202006
2#LOCAL_PEOPLE_DONG_202006.csv
path = 'D:/데이터/유동인구/LOCAL_PEOPLE_DONG_202001.csv' 
b =pd.read_csv(path,sep=',',encoding='utf-8') 

# 주어진 데이터의 컬럼 파트가 3개 라인을 사용하고 있어서 실제 데이터가 아닌 부분도 데이터로 표현이 된다.
# Case.columns =  [ '케이스번호','도시이름','구이름','그룹유무','감염경로','몇번째확진자','위도','경도']
# b.reset_index(inplace=True)
# bcolumns = b.columns
# bcolumns 
# b.drop('여자70세이상생활인구수',axis=1,inplace=True)
# b.columns =  bcolumns[1:]

# %%
b
# Out:
#                                                          기준일ID      시간대구분  \
# 20200101 0  11620625 24188.5806 870.1487  439.6648    453.6983   683.2883
#             11140605 6716.5334  89.0565   36.2822      78.8508   225.3331
#             11470640 46603.6243 2164.9685 1254.3274  1296.7883  1076.9660
#             11290780 9589.1813  390.6835  244.4328    192.6254   240.5164
#             11320512 29984.1309 1005.9128 506.6446    637.8008   721.4613
# ...                                                        ...        ...
# 20200131 23 11260690 20052.7278 784.8522  457.1949    526.8845   426.1374
#             11140570 7758.9907  143.6706  47.8903     187.4134   509.5091
#             11590605 34441.9618 1054.0754 489.3910    760.0268  1650.0129
#             11215760 17221.9293 535.6532  264.8733    357.2389   398.5186
#             11200580 15466.1528 629.6817  386.2273    387.2891   266.1634
#
#                                                          행정동코드     총생활인구수  \
# ...

# %%
df = pd.concat(dfList,sort=False)

# %%
df
# Out:
#                                                          기준일ID      시간대구분  \
# 20170201 0  11110515 14905.2320 565.8853  360.5835    405.1086   589.5560
#             11110530 18336.8186 359.8342  159.9262    213.7376   720.0792
#             11110540 4233.0345  64.6494   49.5368     119.1041   220.3922
#             11110550 11628.9183 266.6229  206.7356    330.2458   385.8279
#             11110560 25155.4005 636.5953  460.4703    633.9927   782.0635
# ...                                                        ...        ...
# 20170228 23 11740650 30617.9765 841.9938  292.0766    656.9691  1000.5545
#             11740660 33629.5517 913.0094  548.8090   1107.6129  1179.3479
#             11740685 61176.0497 2166.0101 1047.4096  1422.3902  1620.9630
#             11740690 15062.2880 306.3420  232.1755    670.3566   595.3452
#             11740700 38440.4324 1527.5537 770.5807   1022.0582  1135.2642
#
#                                                          행정동코드     총생활인구수  \
# ...

# %%
len(b['행정동코드'].unique()) , len(a['행정동코드'].unique())
# Out:
# (424, 425)

# %%
#11500611
b['행정동코드'].unique().sort()
# a['행정동코드'].unique()
b['행정동코드'].min()
b.shape
# Out:
# (305280, 32)

# %%
a['행정동코드'].min()
a.shape
a2.shape
# Out:
# (731, 2)

# %%
pd.merge(b,a, on='행정동코드')
# Out:
#            기준일ID  시간대구분     행정동코드      총생활인구수  남자0세부터9세생활인구수  남자10세부터14세생활인구수  \
# 0       20200601      0  11110515  14493.2553       524.8395         334.4289
# 1       20200601      0  11110515  14493.2553       524.8395         334.4289
# 2       20200601      0  11110515  14493.2553       524.8395         334.4289
# 3       20200601      0  11110515  14493.2553       524.8395         334.4289
# 4       20200601      0  11110515  14493.2553       524.8395         334.4289
# ...          ...    ...       ...         ...            ...              ...
# 519115  20200630     21  11500611  35834.9557      2097.1081        1124.1170
# 519116  20200630     22  11500611  36109.8877      2160.3213        1158.0011
# 519117  20200630     22  11500611  36109.8877      2160.3213        1158.0011
# 519118  20200630     23  11500611  36117.4931      2101.2565        1126.3401
# 519119  20200630     23  11500611  36117.4931      2101.2565        1126.3401
#
# ...

# %%
c = pd.merge(left=b,right=a2,how='right', left_on='행정동코드',right_on='행정동코드')

# %%
len(c[c['행정동'].isna() ==True])
# Out:
# 1

# %%
# # 행정동 코드 
# # 유동인구 202006
# 2#LOCAL_PEOPLE_DONG_202006.csv
# for i in range(42) :
#     path = f'D:/데이터/유동인구/LOCAL_PEOPLE_DONG_{year[i]}.csv' 
#     b =pd.read_csv(path,encoding='utf-8')
#     # 주어진 데이터의 컬럼 파트가 3개 라인을 사용하고 있어서 실제 데이터가 아닌 부분도 데이터로 표현이 된다.
#     # Case.columns =  [ '케이스번호','도시이름','구이름','그룹유무','감염경로','몇번째확진자','위도','경도']
#     b.reset_index(inplace=True)
#     bcolumns = b.columns

#     b.drop('여자70세이상생활인구수',axis=1,inplace=True)
#     b.drop('여자55세부터59세생활인구수',axis=1,inplace=True)
#     b.drop('여자50세부터54세생활인구수',axis=1,inplace=True)
#     b.drop('여자65세부터69세생활인구수',axis=1,inplace=True)
#     b.drop('여자60세부터64세생활인구수',axis=1,inplace=True)
#     b.drop('여자45세부터49세생활인구수',axis=1,inplace=True)


#     b.columns =  bcolumns[6:]
#     print(i)
#     if i == 0 :
#         b0 =b
#     elif i ==1 :
#         realb =pd.concat([b,b0])
#     else :
#         realb = pd.concat([realb,b])
# Out:
# 0
# 1
# 2
# ---------------------------------------------------------------------------
# MemoryError                               Traceback (most recent call last)
# <ipython-input-22-c9797c396424> in <module>
#      25         realb =pd.concat([b,b0])
#      26     else :
# ---> 27         realb = pd.concat([realb,b])
#      28
#      29
#
# c:\users\master\appdata\local\programs\python\python37-32\lib\site-packages\pandas\core\reshape\concat.py in concat(objs, axis, join, ignore_index, keys, levels, names, verify_integrity, sort, copy)
#     282     )
#     283
# --> 284     return op.get_result()
#     285
#     286
#
# c:\users\master\appdata\local\programs\python\python37-32\lib\site-packages\pandas\core\reshape\concat.py in get_result(self)
#     495
#     496             new_data = concatenate_block_managers(
# --> 497                 mgrs_indexers, self.new_axes, concat_axis=self.axis, copy=self.copy
#     498             )
#     499             if not self.copy:
#
# ...

# %%
pip install pymysql
# Out:
# ...
#
# ...

# %%
pip install sqlalchemy
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
# python <-> maridb (계열 mysql)
import pymysql
# 데이터베이스의 대량작업, 객체 연결등등 고차원 작업 진행 지원 모듈
from sqlalchemy import create_engine
# Dataframe을 sql에 전송하는 기능
import pandas.io.sql as pSql
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import matplotlib

# %%
year1=list(map(lambda x: 201701+x, range(12))) 
year2=list(map(lambda x: 201801+x, range(2)))

year3=list(map(lambda x: 201803+x, range(5))) 
year4=list(map(lambda x: 201905+x, range(8))) 
year5= list(map(lambda x: 202002+x, range(5)))
year =year1+year2
len(year)
year3
year4
year5
# Out:
# [202002, 202003, 202004, 202005, 202006]

# %%
# 행정동 코드 
# 유동인구 202006
2#LOCAL_PEOPLE_DONG_202006.csv

path = 'D:/데이터/유동인구/LOCAL_PEOPLE_DONG_201701.csv' 
df =pd.read_csv(path,sep=',',encoding='utf-8') 

# 주어진 데이터의 컬럼 파트가 3개 라인을 사용하고 있어서 실제 데이터가 아닌 부분도 데이터로 표현이 된다.
# Case.columns =  [ '케이스번호','도시이름','구이름','그룹유무','감염경로','몇번째확진자','위도','경도']
df.reset_index(inplace=True)
bcolumns = df.columns

df.drop('여자70세이상생활인구수',axis=1,inplace=True)
df.drop('여자55세부터59세생활인구수',axis=1,inplace=True)
df.drop('여자50세부터54세생활인구수',axis=1,inplace=True)
df.drop('여자65세부터69세생활인구수',axis=1,inplace=True)
df.drop('여자60세부터64세생활인구수',axis=1,inplace=True)
df.drop('여자45세부터49세생활인구수',axis=1,inplace=True)
df.columns =  bcolumns[6:]

# %%
df.head()
# Out:
#       기준일ID  시간대구분     행정동코드      총생활인구수  남자0세부터9세생활인구수  남자10세부터14세생활인구수  \
# 0  20170101      0  11110515  16846.9908       551.1680         351.2056
# 1  20170101      0  11110530  25606.3679       725.4355         322.4155
# 2  20170101      0  11110540   5724.9509        87.0075          66.6684
# 3  20170101      0  11110550  11691.6393       300.6513         233.1209
# 4  20170101      0  11110560  24976.4805       590.4086         427.0619
#
#    남자15세부터19세생활인구수  남자20세부터24세생활인구수  남자25세부터29세생활인구수  남자30세부터34세생활인구수  ...  \
# 0         369.8000        1304.6177         850.2599         754.2146  ...
# 1         532.2063        1224.8244        1204.7807        1075.2772  ...
# 2         105.3054         524.3655         509.7949         358.1338  ...
# 3         322.6515         411.5216         323.3993         295.2344  ...
# 4         631.2858         742.1176         616.4945         550.0281  ...
#
#    여자25세부터29세생활인구수  여자30세부터34세생활인구수  여자35세부터39세생활인구수  여자40세부터44세생활인구수  \
# ...

# %%
# 1. 연결 문자열 생성
id      = 'root'
pwd     = '12341234'
domain  = 'localhost'
port    = '3306'
database= 'test'
db_url  = f'mysql+pymysql://{id}:{pwd}@{domain}:{port}/{database}'
db_url
# Out:
# 'mysql+pymysql://root:12341234@localhost:3306/test'

# %%
# 2. 연결 엔진 생성
engine = create_engine( db_url, encoding='utf8' )
# 3. 실제 연결
conn = engine.connect()
# 4. 데이터 입력
df.to_sql( name='local_people_dong', con=conn, if_exists='append', index=False )
# 5. I/O를 수행하면 반드시 닫는다!!
conn.close()

# %%
# 행정동 코드 
# 유동인구 202006
2#LOCAL_PEOPLE_DONG_202006.csv
# 201701~201802
for i in range(14) :
    path = f'D:/데이터/유동인구/LOCAL_PEOPLE_DONG_{year[i]}.csv' 
    df =pd.read_csv(path,sep=',',encoding='utf-8') 

    # 주어진 데이터의 컬럼 파트가 3개 라인을 사용하고 있어서 실제 데이터가 아닌 부분도 데이터로 표현이 된다.
    # Case.columns =  [ '케이스번호','도시이름','구이름','그룹유무','감염경로','몇번째확진자','위도','경도']
    df.reset_index(inplace=True)
    bcolumns = df.columns

    df.drop('여자70세이상생활인구수',axis=1,inplace=True)
    df.drop('여자55세부터59세생활인구수',axis=1,inplace=True)
    df.drop('여자50세부터54세생활인구수',axis=1,inplace=True)
    df.drop('여자65세부터69세생활인구수',axis=1,inplace=True)
    df.drop('여자60세부터64세생활인구수',axis=1,inplace=True)
    df.drop('여자45세부터49세생활인구수',axis=1,inplace=True)
    df.columns =  bcolumns[6:]
    # 2. 연결 엔진 생성
    engine = create_engine( db_url, encoding='utf8' )
    # 3. 실제 연결
    conn = engine.connect()
    # 4. 데이터 입력
    df.to_sql( name='local_people_dong', con=conn, if_exists='append', index=False )
    # 5. I/O를 수행하면 반드시 닫는다!!
    conn.close()

# %%
path = f'D:/데이터/유동인구/LOCAL_PEOPLE_DONG_201803.csv' 
df =pd.read_csv(path,sep=',',encoding='utf-8') 

# 주어진 데이터의 컬럼 파트가 3개 라인을 사용하고 있어서 실제 데이터가 아닌 부분도 데이터로 표현이 된다.
# Case.columns =  [ '케이스번호','도시이름','구이름','그룹유무','감염경로','몇번째확진자','위도','경도']
# df.reset_index(inplace=True)
# bcolumns = df.columns

# df.drop('여자70세이상생활인구수',axis=1,inplace=True)
# df.drop('여자55세부터59세생활인구수',axis=1,inplace=True)
# df.drop('여자50세부터54세생활인구수',axis=1,inplace=True)
# df.drop('여자65세부터69세생활인구수',axis=1,inplace=True)
# df.drop('여자60세부터64세생활인구수',axis=1,inplace=True)
# df.drop('여자45세부터49세생활인구수',axis=1,inplace=True)
# df.columns =  bcolumns[6:]

# %%
# 행정동 코드 
# 유동인구 202006
2#LOCAL_PEOPLE_DONG_202006.csv
#201803~201807 
for i in range(len(year3)) :
    path = f'D:/데이터/유동인구/LOCAL_PEOPLE_DONG_{year3[i]}.csv' 
    df =pd.read_csv(path,sep=',',encoding='utf-8') 
    df.reset_index(inplace=True)
    realcolumns = df.columns[1:]
    df.drop('여자70세이상생활인구수',axis=1,inplace=True)
    df.columns =  realcolumns
    # 2. 연결 엔진 생성
    engine = create_engine( db_url, encoding='utf8' )
    # 3. 실제 연결
    conn = engine.connect()
    # 4. 데이터 입력
    df.to_sql( name='local_people_dong', con=conn, if_exists='append', index=False )
    # 5. I/O를 수행하면 반드시 닫는다!!
    conn.close()

# %%
# 행정동 코드 
# 유동인구 202006
2#LOCAL_PEOPLE_DONG_202006.csv
#201808~201807 
for i in range(len(year3)) :
    path = f'D:/데이터/유동인구/LOCAL_PEOPLE_DONG_{year3[i]}.csv' 
    df =pd.read_csv(path,sep=',',encoding='utf-8') 
    df.reset_index(inplace=True)
    realcolumns = df.columns[1:]
    df.drop('여자70세이상생활인구수',axis=1,inplace=True)
    df.columns =  realcolumns
    # 2. 연결 엔진 생성
    engine = create_engine( db_url, encoding='utf8' )
    # 3. 실제 연결
    conn = engine.connect()
    # 4. 데이터 입력
    df.to_sql( name='local_people_dong', con=conn, if_exists='append', index=False )
    # 5. I/O를 수행하면 반드시 닫는다!!
    conn.close()

# %%
path = f'D:/데이터/유동인구/LOCAL_PEOPLE_DONG_201808.csv' 
df =pd.read_csv(path,sep=',',encoding='utf-8') 
df.reset_index(inplace=True)
bcolumns = df.columns

df.drop('여자70세이상생활인구수',axis=1,inplace=True)
df.drop('여자55세부터59세생활인구수',axis=1,inplace=True)
df.drop('여자50세부터54세생활인구수',axis=1,inplace=True)
df.drop('여자65세부터69세생활인구수',axis=1,inplace=True)
df.drop('여자60세부터64세생활인구수',axis=1,inplace=True)
df.drop('여자45세부터49세생활인구수',axis=1,inplace=True)
df.columns =  bcolumns[6:]
# 2. 연결 엔진 생성
engine = create_engine( db_url, encoding='utf8' )
# 3. 실제 연결
conn = engine.connect()
# 4. 데이터 입력
df.to_sql( name='local_people_dong', con=conn, if_exists='append', index=False )
# 5. I/O를 수행하면 반드시 닫는다!!
conn.close()

# %%
path = f'D:/데이터/유동인구/LOCAL_PEOPLE_DONG_201809.csv' 
df =pd.read_csv(path,sep=',',encoding='utf-8') 
df.reset_index(inplace=True)
bcolumns = df.columns

df.drop('여자70세이상생활인구수',axis=1,inplace=True)
df.drop('여자55세부터59세생활인구수',axis=1,inplace=True)
df.drop('여자50세부터54세생활인구수',axis=1,inplace=True)
df.drop('여자65세부터69세생활인구수',axis=1,inplace=True)
df.drop('여자60세부터64세생활인구수',axis=1,inplace=True)
df.drop('여자45세부터49세생활인구수',axis=1,inplace=True)
df.columns =  bcolumns[6:]
# 2. 연결 엔진 생성
engine = create_engine( db_url, encoding='utf8' )
# 3. 실제 연결
conn = engine.connect()
# 4. 데이터 입력
df.to_sql( name='local_people_dong', con=conn, if_exists='append', index=False )
# 5. I/O를 수행하면 반드시 닫는다!!
conn.close()

# %%
path = f'D:/데이터/유동인구/LOCAL_PEOPLE_DONG_201810.csv' 
df =pd.read_csv(path,sep=',',encoding='utf-8') 
df.reset_index(inplace=True)
realcolumns = df.columns[1:]
df.drop('여자70세이상생활인구수',axis=1,inplace=True)
df.columns =  realcolumns
# 2. 연결 엔진 생성
engine = create_engine( db_url, encoding='utf8' )
# 3. 실제 연결
conn = engine.connect()
# 4. 데이터 입력
df.to_sql( name='local_people_dong', con=conn, if_exists='append', index=False )
# 5. I/O를 수행하면 반드시 닫는다!!
conn.close()

# %%
path = f'D:/데이터/유동인구/LOCAL_PEOPLE_DONG_201811.csv' 
df =pd.read_csv(path,sep=',',encoding='utf-8',error_bad_lines=False) 
df.reset_index(inplace=True)
realcolumns = df.columns[1:]
df.drop('여자70세이상생활인구수',axis=1,inplace=True)
df.columns =  realcolumns
df
# Out:
# IOPub data rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_data_rate_limit`.
#
# Current values:
# NotebookApp.iopub_data_rate_limit=1000000.0 (bytes/sec)
# NotebookApp.rate_limit_window=3.0 (secs)
#            기준일ID  시간대구분     행정동코드      총생활인구수  남자0세부터9세생활인구수  남자10세부터14세생활인구수  \
# 0       20181101      0  11110515  14799.0314       489.8446         312.1301
# 1       20181101      0  11110540   5072.4639        68.5522          52.5271
# 2       20181101      0  11110550  13510.7258       296.9959         230.2863
# 3       20181101      0  11110560  22047.6664       631.9267         457.0936
# 4       20181101      0  11170530  10764.3579       210.1115         101.3827
# ...          ...    ...       ...         ...            ...              ...
# 223867  20181122     23  11200550  22422.1069       301.7550         137.5647
# ...

# %%
df
# Out:
#            기준일ID  시간대구분     행정동코드      총생활인구수  남자0세부터9세생활인구수  남자10세부터14세생활인구수  \
# 0       20181101      0  11110515  14799.0314       489.8446         312.1301
# 1       20181101      0  11110540   5072.4639        68.5522          52.5271
# 2       20181101      0  11110550  13510.7258       296.9959         230.2863
# 3       20181101      0  11110560  22047.6664       631.9267         457.0936
# 4       20181101      0  11170530  10764.3579       210.1115         101.3827
# ...          ...    ...       ...         ...            ...              ...
# 223867  20181122     23  11200550  22422.1069       301.7550         137.5647
# 223868  20181122     23  11305534  28352.7072      1082.9933         616.6897
# 223869  20181122     23  11590670  19779.1202       667.9268         431.0042
# 223870  20181122     23  11470610   5341.2188       225.4574         147.4146
# 223871  20181122     23  11320670  19121.0121       733.0656         377.2679
#
# ...

# %%
# 201811 

# 2. 연결 엔진 생성
engine = create_engine( db_url, encoding='utf8' )
# 3. 실제 연결
conn = engine.connect()
# 4. 데이터 입력
df.to_sql( name='local_people_dong', con=conn, if_exists='append', index=False )
# 5. I/O를 수행하면 반드시 닫는다!!
conn.close()

# %%
path = f'D:/데이터/유동인구/LOCAL_PEOPLE_DONG_201812.csv' 
df =pd.read_csv(path,sep=',',encoding='utf-8')
df.reset_index(inplace=True)
bcolumns = df.columns

df.drop('여자70세이상생활인구수',axis=1,inplace=True)
df.drop('여자55세부터59세생활인구수',axis=1,inplace=True)
df.drop('여자50세부터54세생활인구수',axis=1,inplace=True)
df.drop('여자65세부터69세생활인구수',axis=1,inplace=True)
df.drop('여자60세부터64세생활인구수',axis=1,inplace=True)
df.drop('여자45세부터49세생활인구수',axis=1,inplace=True)
df.columns =  bcolumns[6:]
# 2. 연결 엔진 생성
engine = create_engine( db_url, encoding='utf8' )
# 3. 실제 연결
conn = engine.connect()
# 4. 데이터 입력
df.to_sql( name='local_people_dong', con=conn, if_exists='append', index=False )
# 5. I/O를 수행하면 반드시 닫는다!!
conn.close()

# %%
path = f'D:/데이터/유동인구/LOCAL_PEOPLE_DONG_201901.csv' 
df =pd.read_csv(path,sep=',',encoding='utf-8')
df.reset_index(inplace=True)
bcolumns = df.columns

df.drop('여자70세이상생활인구수',axis=1,inplace=True)
df.drop('여자55세부터59세생활인구수',axis=1,inplace=True)
df.drop('여자50세부터54세생활인구수',axis=1,inplace=True)
df.drop('여자65세부터69세생활인구수',axis=1,inplace=True)
df.drop('여자60세부터64세생활인구수',axis=1,inplace=True)
df.drop('여자45세부터49세생활인구수',axis=1,inplace=True)
df.columns =  bcolumns[6:]
# 2. 연결 엔진 생성
engine = create_engine( db_url, encoding='utf8' )
# 3. 실제 연결
conn = engine.connect()
# 4. 데이터 입력
df.to_sql( name='local_people_dong', con=conn, if_exists='append', index=False )
# 5. I/O를 수행하면 반드시 닫는다!!
conn.close()

# %%
path = f'D:/데이터/유동인구/LOCAL_PEOPLE_DONG_201902.csv' 
df =pd.read_csv(path,sep=',',encoding='utf-8')
df.reset_index(inplace=True)
realcolumns = df.columns[1:]
df.drop('여자70세이상생활인구수',axis=1,inplace=True)
df.columns =  realcolumns
# 2. 연결 엔진 생성
engine = create_engine( db_url, encoding='utf8' )
# 3. 실제 연결
conn = engine.connect()
# 4. 데이터 입력
df.to_sql( name='local_people_dong', con=conn, if_exists='append', index=False )
# 5. I/O를 수행하면 반드시 닫는다!!
conn.close()

# %%
path = f'D:/데이터/유동인구/LOCAL_PEOPLE_DONG_201903.csv' 
df =pd.read_csv(path,sep=',',encoding='utf-8')
df.reset_index(inplace=True)
bcolumns = df.columns

df.drop('여자70세이상생활인구수',axis=1,inplace=True)
df.drop('여자55세부터59세생활인구수',axis=1,inplace=True)
df.drop('여자50세부터54세생활인구수',axis=1,inplace=True)
df.drop('여자65세부터69세생활인구수',axis=1,inplace=True)
df.drop('여자60세부터64세생활인구수',axis=1,inplace=True)
df.drop('여자45세부터49세생활인구수',axis=1,inplace=True)
df.columns =  bcolumns[6:]
# 2. 연결 엔진 생성
engine = create_engine( db_url, encoding='utf8' )
# 3. 실제 연결
conn = engine.connect()
# 4. 데이터 입력
df.to_sql( name='local_people_dong', con=conn, if_exists='append', index=False )
# 5. I/O를 수행하면 반드시 닫는다!!
conn.close()

# %%
path = f'D:/데이터/유동인구/LOCAL_PEOPLE_DONG_201904.csv' 
df =pd.read_csv(path,sep=',',encoding='utf-8')
df.reset_index(inplace=True)
realcolumns = df.columns[1:]
df.drop('여자70세이상생활인구수',axis=1,inplace=True)
df.columns =  realcolumns
# 2. 연결 엔진 생성
engine = create_engine( db_url, encoding='utf8' )
# 3. 실제 연결
conn = engine.connect()
# 4. 데이터 입력
df.to_sql( name='local_people_dong', con=conn, if_exists='append', index=False )
# 5. I/O를 수행하면 반드시 닫는다!!
conn.close()

# %%
#2019-05 ~ 2019-12
for i in range(len(year4)) :
    path = f'D:/데이터/유동인구/LOCAL_PEOPLE_DONG_{year4[i]}.csv' 
    df =pd.read_csv(path,sep=',',encoding='utf-8')
    df.reset_index(inplace=True)
    realcolumns = df.columns[1:]
    df.drop('여자70세이상생활인구수',axis=1,inplace=True)
    df.columns =  realcolumns
    # 2. 연결 엔진 생성
    engine = create_engine( db_url, encoding='utf8' )
    # 3. 실제 연결
    conn = engine.connect()
    # 4. 데이터 입력
    df.to_sql( name='local_people_dong', con=conn, if_exists='append', index=False )
    # 5. I/O를 수행하면 반드시 닫는다!!
    conn.close()

# %%
path = f'D:/데이터/유동인구/LOCAL_PEOPLE_DONG_202001.csv' 
df =pd.read_csv(path,sep=',',encoding='utf-8')
df.reset_index(inplace=True)
bcolumns = df.columns

df.drop('여자70세이상생활인구수',axis=1,inplace=True)
df.drop('여자55세부터59세생활인구수',axis=1,inplace=True)
df.drop('여자50세부터54세생활인구수',axis=1,inplace=True)
df.drop('여자65세부터69세생활인구수',axis=1,inplace=True)
df.drop('여자60세부터64세생활인구수',axis=1,inplace=True)
df.drop('여자45세부터49세생활인구수',axis=1,inplace=True)
df.columns =  bcolumns[6:]
 # 2. 연결 엔진 생성
engine = create_engine( db_url, encoding='utf8' )
# 3. 실제 연결
conn = engine.connect()
# 4. 데이터 입력
df.to_sql( name='local_people_dong', con=conn, if_exists='append', index=False )
# 5. I/O를 수행하면 반드시 닫는다!!
conn.close()

# %%
#202002~202006
for i in range(len(year5)) :
    path = f'D:/데이터/유동인구/LOCAL_PEOPLE_DONG_{year5[i]}.csv' 
    df =pd.read_csv(path,sep=',',encoding='utf-8')
    df.reset_index(inplace=True)
    realcolumns = df.columns[1:]
    df.drop('여자70세이상생활인구수',axis=1,inplace=True)
    df.columns =  realcolumns
 # 2. 연결 엔진 생성
    engine = create_engine( db_url, encoding='utf8' )
    # 3. 실제 연결
    conn = engine.connect()
    # 4. 데이터 입력
    df.to_sql( name='local_people_dong', con=conn, if_exists='append', index=False )
    # 5. I/O를 수행하면 반드시 닫는다!!
    conn.close()

# %%
# Out:
#            기준일ID  시간대구분     행정동코드      총생활인구수  남자0세부터9세생활인구수  남자10세부터14세생활인구수  \
# 0       20200201      0  11440730  40008.7419      1346.3171         841.9587
# 1       20200201      0  11650621  26212.2534       789.3616         519.2963
# 2       20200201      0  11215830  23724.4049       762.3188         356.6239
# 3       20200201      0  11290770  14879.6820       554.3716         386.5561
# 4       20200201      0  11305555  30307.1826       998.5169         552.0452
# ...          ...    ...       ...         ...            ...              ...
# 295099  20200229     23  11110550  15557.0453       420.3440         325.9288
# 295100  20200229     23  11110630   9260.5173       113.2755          86.2242
# 295101  20200229     23  11110580   6347.2259       326.8050         130.0039
# 295102  20200229     23  11110615  21882.7250       288.8278          91.0007
# 295103  20200229     23  11110600   4972.7796        46.4308          32.7747
#
# ...

# %%
import folium

# %%
folium.__version__

# %%
# gps =[37.5511694,126.9860379]
# map = folium.Map(location= gps ,zoom_start= 11)
# for i in seoul[['위도','경도','거점명']].values:
#     folium.Marker([i[0]	,i[1]],popup=i[2],icon= folium.Icon(icon='cloud')).add_to(map)
# map

# %%
# ab= aa.iloc[:,0:3]
# ab.drop_duplicates('행정동코드',inplace=True)
# ab
