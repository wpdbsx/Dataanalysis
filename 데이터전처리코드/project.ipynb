# %%
import pandas as pd

# %%
path = '/content/행정동별 서울생활인구(내국인).csv'
population_df = pd.read_csv(path, encoding = 'CP949')

# %%
population_df.head()
# Out:
#       기준일ID  시간대구분     행정동코드  ...  여자60세부터64세생활인구수  여자65세부터69세생활인구수  여자70세이상생활인구수
# 0  20200718      0  11110515  ...         400.2615         349.8190     1102.9326
# 1  20200718      0  11110530  ...         499.3031         343.2849     1299.5559
# 2  20200718      0  11110540  ...         167.1671         163.0233      333.4202
# 3  20200718      0  11110550  ...         611.3582         397.5532     1311.9385
# 4  20200718      0  11110560  ...         916.4877         663.8578     1904.3802
#
# [5 rows x 32 columns]

# %%
dong =population_df['행정동코드'].unique()
dong
# Out:
# array([11110515, 11110530, 11110540, 11110550, 11110560, 11110570,
#        11110580, 11110600, 11110615, 11110630, 11110640, 11110650,
#        11110670, 11110680, 11110690, 11110700, 11110710, 11140520,
#        11140540, 11140550, 11140570, 11140580, 11140590, 11140605,
#        11140615, 11140625, 11140635, 11140645, 11140650, 11140665,
#        11140670, 11140680, 11170510, 11170520, 11170530, 11170555,
#        11170560, 11170570, 11170580, 11170590, 11170625, 11170630,
#        11170640, 11170650, 11170660, 11170685, 11170690, 11170700,
#        11200520, 11200535, 11200540, 11200550, 11200560, 11200570,
#        11200580, 11200590, 11200615, 11200620, 11200645, 11200650,
#        11200660, 11200670, 11200690, 11200720, 11200790, 11215710,
#        11215730, 11215740, 11215750, 11215760, 11215770, 11215780,
#        11215810, 11215820, 11215830, 11215840, 11215847, 11215850,
#        11215860, 11215870, 11230536, 11230545, 11230560, 11230570,
# ...

# %%
# tmp = crime2018DF.sort_values(by = '검거', ascending= False)[cols]
dong.sort
dong
# Out:
# array([11110515, 11110530, 11110540, 11110550, 11110560, 11110570,
#        11110580, 11110600, 11110615, 11110630, 11110640, 11110650,
#        11110670, 11110680, 11110690, 11110700, 11110710, 11140520,
#        11140540, 11140550, 11140570, 11140580, 11140590, 11140605,
#        11140615, 11140625, 11140635, 11140645, 11140650, 11140665,
#        11140670, 11140680, 11170510, 11170520, 11170530, 11170555,
#        11170560, 11170570, 11170580, 11170590, 11170625, 11170630,
#        11170640, 11170650, 11170660, 11170685, 11170690, 11170700,
#        11200520, 11200535, 11200540, 11200550, 11200560, 11200570,
#        11200580, 11200590, 11200615, 11200620, 11200645, 11200650,
#        11200660, 11200670, 11200690, 11200720, 11200790, 11215710,
#        11215730, 11215740, 11215750, 11215760, 11215770, 11215780,
#        11215810, 11215820, 11215830, 11215840, 11215847, 11215850,
#        11215860, 11215870, 11230536, 11230545, 11230560, 11230570,
# ...

# %%
path = '/content/서울시_행정_법정동_코드.xlsx'
dongcode_df = pd.read_excel(path, encoding = 'utf-8')

# %%
dongcode_df.head()

# %%
dongcode_df['행정동코드'].unique().shape

# %%
df_LEFT_JOIN = pd.merge( population_df,dongcode_df, left_on='행정동코드', right_on='행정동코드', how='left')
df_LEFT_JOIN.head()
# Out:
#       기준일ID  시간대구분     행정동코드     총생활인구수  ...  자치구    행정동       법정동코드  법정동
# 0  20200718      0  11110515  14402.747  ...  종로구  청운효자동  11110101.0  청운동
# 1  20200718      0  11110515  14402.747  ...  종로구  청운효자동  11110102.0  신교동
# 2  20200718      0  11110515  14402.747  ...  종로구  청운효자동  11110103.0  궁정동
# 3  20200718      0  11110515  14402.747  ...  종로구  청운효자동  11110104.0  효자동
# 4  20200718      0  11110515  14402.747  ...  종로구  청운효자동  11110105.0  창성동
#
# [5 rows x 36 columns]

# %%
from google.colab import drive
drive.mount('/content/drive')
